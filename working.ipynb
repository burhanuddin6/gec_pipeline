# %%
print("Contents of data_00.txt:")
# !type C:\Users\Admin\gec_pipeline\data\cleaned_correct_corpus\data_00.txt

print("\nContents of output incorrect file:")
# !type C:\Users\Admin\gec_pipeline\data\out\incorrect.txt

print("\nContents of output correct file:")
# !type C:\Users\Admin\gec_pipeline\data\out\correct.txt

print("\nContents of input incorrect file:")
# !type C:\Users\Admin\gec_pipeline\data\wikiedits\train_incorrect.txt

print("\nContents of input correct file:")
# !type C:\Users\Admin\gec_pipeline\data\wikiedits\train_correct.txt

print("\nContents of processed lines log file:")
# !type C:\Users\Admin\gec_pipeline\logs\num_processed_lines.txt

print("\nContents of annotations so far:")
# !type C:\Users\Admin\gec_pipeline\data\annotations.json

print("\nContents of annotations with ids so far:")
# !type C:\Users\Admin\gec_pipeline\data\annotations_with_ids.json

print("\nRunning the annotation script:")
# !cd C:\Users\Admin\gec_pipeline && python -m error_annotation.annotation_stanza

print("\nContents of processed lines log file after running annotation:")
# !type C:\Users\Admin\gec_pipeline\logs\num_processed_lines.txt

print("\nRunning the id-assigning script on the annotations dictionary:")
# !cd C:\Users\Admin\gec_pipeline && python -m data_generation.assign_error_ids

print("\nContents of annotations after running annotation:")
# !type C:\Users\Admin\gec_pipeline\data\annotations.json

print("\nContents of annotations with ids after running annotation:")
# !type C:\Users\Admin\gec_pipeline\data\annotations_with_ids.json

print("\nContents of word dictionary having the incorrect transitioning word with those exact features:")
# !chcp 65001 & powershell -Command "$OutputEncoding = [System.Text.Encoding]::UTF8; (Get-Content 'C:\Users\Admin\gec_pipeline\data\urdu_word_dict.json' -Encoding UTF8)[1721..1733]"

print("\nContents of word dictionary having the correct transitioning word with those exact features:")
# !chcp 65001 & powershell -Command "$OutputEncoding = [System.Text.Encoding]::UTF8; (Get-Content 'C:\Users\Admin\gec_pipeline\data\urdu_word_dict.json' -Encoding UTF8)[1079..1091]"

print("\nContents of lemma dictionary having the both incorrect and correct words:")
# !chcp 65001 & powershell -Command "$OutputEncoding = [System.Text.Encoding]::UTF8; (Get-Content 'C:\Users\Admin\gec_pipeline\data\lemma_word_dict.json' -Encoding UTF8)[31..39]"

print("\nRunning the infliction script:")
# !cd C:\Users\Admin\gec_pipeline && python -m error_annotation.infliction_stanza

print("\nContents of output incorrect file:")
# !type C:\Users\Admin\gec_pipeline\data\out\incorrect.txt

print("\nContents of output correct file:")
# !type C:\Users\Admin\gec_pipeline\data\out\correct.txt
# Out:
# Contents of data_00.txt:
# حکومت نے مسائل حل کرنے کی اجازت دے دی۔
#
# Contents of output incorrect file:
#
# Contents of output correct file:
#
# Contents of input incorrect file:
# حکومت نے مسائل حل کرنے کا اجازت دے دی۔
#
# Contents of input correct file:
# حکومت نے مسائل حل کرنے کی اجازت دے دی۔
#
# Contents of processed lines log file:
# 0
#
# Contents of annotations so far:
#
# Contents of annotations with ids so far:
#
# Running the annotation script:
# Starting from line number: 0
# Number of existing annotations: 0
# Initializing Stanza pipeline...
# ✅ Stanza pipeline initialized successfully.
# Annotation complete! Total annotations: 1
#
# Contents of processed lines log file after running annotation:
# 1
#
# Running the id-assigning script on the annotations dictionary:
# Unique IDs assigned and written to data/annotations_with_ids.json
#
# Contents of annotations after running annotation:
# {
#   "['VERB', 'ADP', 'NOUN']": [
#     {
#       "type": "S",
# ...

# %%
print("\nRunning the annotation script:")
# !cd C:\Users\Admin\gec_pipeline && python -m error_annotation.annotation_stanza

print("\nContents of processed lines log file after running annotation:")
# !type C:\Users\Admin\gec_pipeline\logs\num_processed_lines.txt

print("\nRunning the id-assigning script on the annotations dictionary:")
# !cd C:\Users\Admin\gec_pipeline && python -m data_generation.assign_error_ids

print("\nRunning the infliction script:")
# !cd C:\Users\Admin\gec_pipeline && python -m error_annotation.infliction_stanza
# Out:
# Running the annotation script:
# Starting from line number: 0
# Number of existing annotations: 0
# Initializing Stanza pipeline...
# ✅ Stanza pipeline initialized successfully.
# Total lines processed: 100
# Total lines processed: 200
# Total lines processed: 300
# Total lines processed: 400
# Total lines processed: 500
# Total lines processed: 600
# Total lines processed: 700
# Total lines processed: 800
# Total lines processed: 900
# Processed 1000 lines, saved checkpoint
# Total lines processed: 1000
# Total lines processed: 1100
# Total lines processed: 1200
# Total lines processed: 1300
# Total lines processed: 1400
# Total lines processed: 1500
# Total lines processed: 1600
# Total lines processed: 1700
# Total lines processed: 1800
# Total lines processed: 1900
# Processed 2000 lines, saved checkpoint
# Total lines processed: 2000
# Total lines processed: 2100
# Total lines processed: 2200
# Total lines processed: 2300
# Total lines processed: 2400
# ...
